// %% [markdown]
// # Development of functions related to the substructure of jets at parton level

// %% [markdown]
// In this analysis, I use:
// $$ z_{g} = \frac{min(p_{T_{1}}, p_{T_{2}})}{p_{T_{1}} + p_{T_{2}}} $$
// where $p_{T_{1}}$, $p_{T_{2}}$ are the transverse momenta of the subjets and:
// $$ R_{g} = \sqrt{\Delta\eta^{2}+\Delta\phi^{2}} $$
// where $\Delta\eta$, $\Delta\phi$ the angular distance between the subjets.
//
// All variables relate to parton level variables in the tree.

// %% [markdown]
// ## Imports

// %%
!ls
// Out:
// HiTree.C
// HiTree_bjet.C
// Rg_functions.ipynb
// code_bJet.C
// code_incl.C
// draw_zg.C
// draw_zg.C~
// draw_zg_rg_all_flavors.C
// gen_sub.root
// generated_jet_substructure_all_flavors.ipynb
// genptVSrg.jpg
// genptVSzg.jpg
// make_small_tree.C
// make_small_tree.C~
// make_small_tree_C.so
// ntuple_dirs.txt
// parptVSrg.jpg
// parptVSzg.jpg
// parton_jet_substructure_all_flavors.ipynb
// parton_jet_substructure_by_flavor.ipynb
// plot_bJet_zg.C~
// plot_inclusive_zg.C~
// plot_zg.C
// plot_zg.C~
// plot_zg_rg_all_flavors.C
// ref_jet_substructure_all_flavors.ipynb
// rg_proj.jpg
// rg_proj_gen.jpg
// rg_proj_gen.png
// small.root
// small_bJetMC.root
// small_qcdMC.root
// test.C~
// test.ipynb
// test_C.so
// zg.root
// zg_proj.jpg
// zg_proj_gen.jpg

// %%
#include <iostream>
#include "stdio.h"
#include "TFile.h"
#include "TH2.h"
#include "TTree.h"
#include <vector>

// %%
%jsroot on

// %% [markdown]
// ## Examine files

// %%
string path_incl = "/data_CMS/cms/mnguyen//bJet2022/qcdMC/SD/merged_HiForestAOD.root";
string path_bJet = "/data_CMS/cms/mnguyen//bJet2022/bJetMC/SD/merged_HiForestAOD.root";
TFile *f;
TTree *t;
TTree *HiTree;

// %% [markdown]
// Open file to see contents

// %%
f = new TFile(path_incl.c_str());
f->ls();
// Out:
// TFile**		/data_CMS/cms/mnguyen//bJet2022/qcdMC/SD/merged_HiForestAOD.root
//  TFile*		/data_CMS/cms/mnguyen//bJet2022/qcdMC/SD/merged_HiForestAOD.root
//   KEY: TDirectoryFile	hltanalysis;1	hltanalysis
//   KEY: TDirectoryFile	skimanalysis;1	skimanalysis
//   KEY: TDirectoryFile	hiEvtAnalyzer;1	hiEvtAnalyzer
//   KEY: TDirectoryFile	ak4PFJetAnalyzer;1	ak4PFJetAnalyzer
//   KEY: TDirectoryFile	bHadronAna;1	bHadronAna
//   KEY: TDirectoryFile	cHadronAna;1	cHadronAna
//   KEY: TDirectoryFile	outgoingPartonAna;1	outgoingPartonAna
//   KEY: TDirectoryFile	incomingPartonAna;1	incomingPartonAna
//   KEY: TDirectoryFile	HiForest;1	HiForest
//   KEY: TDirectoryFile	runAnalyzer;1	runAnalyzer

// %%
t = (TTree *) f->Get("ak4PFJetAnalyzer/t");
//t->Print();

// %%
t->Print();
// Out:
// ******************************************************************************
// *Tree    :t         : ak4PFpatJetsWithBtagging Jet Analysis Tree             *
// *Entries : 56563000 : Total =     71015533643 bytes  File  Size = 42739069064 *
// *        :          : Tree compression factor =   1.66                       *
// ******************************************************************************
// *Br    0 :nref      : nref/I                                                 *
// *Entries : 56563000 : Total  Size=  227063122 bytes  File Size  =   38701608 *
// *Baskets :     9214 : Basket Size=      32000 bytes  Compression=   5.86     *
// *............................................................................*
// *Br    1 :rawpt     : rawpt[nref]/F                                          *
// *Entries : 56563000 : Total  Size=  798600674 bytes  File Size  =  647161947 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   1.23     *
// *............................................................................*
// *Br    2 :jtpt      : jtpt[nref]/F                                           *
// *Entries : 56563000 : Total  Size=  798568397 bytes  File Size  =  646147573 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   1.23     *
// *............................................................................*
// *Br    3 :jteta     : jteta[nref]/F                                          *
// *Entries : 56563000 : Total  Size=  798600674 bytes  File Size  =  663771959 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   1.20     *
// *............................................................................*
// *Br    4 :jtphi     : jtphi[nref]/F                                          *
// *Entries : 56563000 : Total  Size=  798600674 bytes  File Size  =  661045188 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   1.21     *
// *............................................................................*
// *Br    5 :jtHadFlav : jtHadFlav[nref]/F                                      *
// *Entries : 56563000 : Total  Size=  798729782 bytes  File Size  =  169846909 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   4.70     *
// *............................................................................*
// *Br    6 :jtParFlav : jtParFlav[nref]/F                                      *
// *Entries : 56563000 : Total  Size=  798729782 bytes  File Size  =  256440579 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   3.11     *
// *............................................................................*
// *Br    7 :jtNbHad   : jtNbHad[nref]/I                                        *
// *Entries : 56563000 : Total  Size=  798665221 bytes  File Size  =  142815809 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   5.59     *
// *............................................................................*
// *Br    8 :jtNcHad   : jtNcHad[nref]/I                                        *
// *Entries : 56563000 : Total  Size=  798665221 bytes  File Size  =  168952358 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   4.72     *
// *............................................................................*
// *Br    9 :jtNbPar   : jtNbPar[nref]/I                                        *
// *Entries : 56563000 : Total  Size=  798665221 bytes  File Size  =  142755540 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   5.59     *
// *............................................................................*
// *Br   10 :jtNcPar   : jtNcPar[nref]/I                                        *
// *Entries : 56563000 : Total  Size=  798665221 bytes  File Size  =  158345950 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   5.04     *
// *............................................................................*
// *Br   11 :jtHasGSPB : jtHasGSPB[nref]/O                                      *
// *Entries : 56563000 : Total  Size=  370577248 bytes  File Size  =  133103827 *
// *Baskets :    20004 : Basket Size=      32000 bytes  Compression=   2.78     *
// *............................................................................*
// *Br   12 :jtHasGSPC : jtHasGSPC[nref]/O                                      *
// *Entries : 56563000 : Total  Size=  370577248 bytes  File Size  =  141914193 *
// *Baskets :    20004 : Basket Size=      32000 bytes  Compression=   2.61     *
// *............................................................................*
// *Br   13 :jtIsHardest : jtIsHardest[nref]/O                                  *
// *Entries : 56563000 : Total  Size=  370617264 bytes  File Size  =  168870789 *
// *Baskets :    20004 : Basket Size=      32000 bytes  Compression=   2.19     *
// *............................................................................*
// *Br   14 :sjt1Pt    : sjt1Pt[nref]/F                                         *
// *Entries : 56563000 : Total  Size=  798632951 bytes  File Size  =  645675272 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   1.24     *
// *............................................................................*
// *Br   15 :sjt1Eta   : sjt1Eta[nref]/F                                        *
// *Entries : 56563000 : Total  Size=  798665228 bytes  File Size  =  663605240 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   1.20     *
// *............................................................................*
// *Br   16 :sjt1Phi   : sjt1Phi[nref]/F                                        *
// *Entries : 56563000 : Total  Size=  798665228 bytes  File Size  =  660821228 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   1.21     *
// *............................................................................*
// *Br   17 :sjt1HadFlav : sjt1HadFlav[nref]/F                                  *
// *Entries : 56563000 : Total  Size=  798794336 bytes  File Size  =  165571767 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   4.82     *
// *............................................................................*
// *Br   18 :sjt1ParFlav : sjt1HadFlav[nref]/F                                  *
// *Entries : 56563000 : Total  Size=  798794336 bytes  File Size  =  254872093 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   3.13     *
// *............................................................................*
// *Br   19 :sjt2Pt    : sjt2Pt[nref]/F                                         *
// *Entries : 56563000 : Total  Size=  798632951 bytes  File Size  =  644348197 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   1.24     *
// *............................................................................*
// *Br   20 :sjt2Eta   : sjt2Eta[nref]/F                                        *
// *Entries : 56563000 : Total  Size=  798665228 bytes  File Size  =  660194512 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   1.21     *
// *............................................................................*
// *Br   21 :sjt2Phi   : sjt2Phi[nref]/F                                        *
// *Entries : 56563000 : Total  Size=  798665228 bytes  File Size  =  657528015 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   1.21     *
// *............................................................................*
// *Br   22 :sjt2HadFlav : sjt2HadFlav[nref]/F                                  *
// *Entries : 56563000 : Total  Size=  798794336 bytes  File Size  =  145691772 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   5.48     *
// *............................................................................*
// *Br   23 :sjt2ParFlav : sjt2HadFlav[nref]/F                                  *
// *Entries : 56563000 : Total  Size=  798794336 bytes  File Size  =  241083146 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   3.31     *
// *............................................................................*
// *Br   24 :rsjt1Pt   : rsjt1Pt[nref]/F                                        *
// *Entries : 56563000 : Total  Size=  798665228 bytes  File Size  =  646245845 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   1.23     *
// *............................................................................*
// *Br   25 :rsjt1Eta  : rsjt1Eta[nref]/F                                       *
// *Entries : 56563000 : Total  Size=  798697505 bytes  File Size  =  662359098 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   1.20     *
// *............................................................................*
// *Br   26 :rsjt1Phi  : rsjt1Phi[nref]/F                                       *
// *Entries : 56563000 : Total  Size=  798697505 bytes  File Size  =  659545797 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   1.21     *
// *............................................................................*
// *Br   27 :rsjt2Pt   : rsjt2Pt[nref]/F                                        *
// *Entries : 56563000 : Total  Size=  798665228 bytes  File Size  =  646143891 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   1.24     *
// *............................................................................*
// *Br   28 :rsjt2Eta  : rsjt2Eta[nref]/F                                       *
// *Entries : 56563000 : Total  Size=  798697505 bytes  File Size  =  660794781 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   1.21     *
// *............................................................................*
// *Br   29 :rsjt2Phi  : rsjt2Phi[nref]/F                                       *
// *Entries : 56563000 : Total  Size=  798697505 bytes  File Size  =  658023890 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   1.21     *
// *............................................................................*
// *Br   30 :jtDiscCSVV2 : jtDiscCSVV2[nref]/F                                  *
// *Entries : 56563000 : Total  Size=  798794336 bytes  File Size  =  610946004 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   1.31     *
// *............................................................................*
// *Br   31 :jtDiscDeepCSVB : jtDiscDeepCSVB[nref]/F                            *
// *Entries : 56563000 : Total  Size=  798988051 bytes  File Size  =  615341044 *
// *Baskets :    33187 : Basket Size=      32000 bytes  Compression=   1.30     *
// *............................................................................*
// *Br   32 :jtDiscDeepCSVBB : jtDiscDeepCSVBB[nref]/F                          *
// *Entries : 56563000 : Total  Size=  799021242 bytes  File Size  =  620777558 *
// *Baskets :    33187 : Basket Size=      32000 bytes  Compression=   1.29     *
// *............................................................................*
// *Br   33 :jtDiscDeepCSVC : jtDiscDeepCSVC[nref]/F                            *
// *Entries : 56563000 : Total  Size=  798988051 bytes  File Size  =  607675615 *
// *Baskets :    33187 : Basket Size=      32000 bytes  Compression=   1.31     *
// *............................................................................*
// *Br   34 :jtDiscDeepFlavourB : jtDiscDeepFlavourB[nref]/F                    *
// *Entries : 56563000 : Total  Size=  799144245 bytes  File Size  =  650891286 *
// *Baskets :    33400 : Basket Size=      32000 bytes  Compression=   1.23     *
// *............................................................................*
// *Br   35 :jtDiscDeepFlavourBB : jtDiscDeepFlavourBB[nref]/F                  *
// *Entries : 56563000 : Total  Size=  799177649 bytes  File Size  =  660000933 *
// *Baskets :    33400 : Basket Size=      32000 bytes  Compression=   1.21     *
// *............................................................................*
// *Br   36 :jtDiscDeepFlavourLEPB : jtDiscDeepFlavourLEPB[nref]/F              *
// *Entries : 56563000 : Total  Size=  799245813 bytes  File Size  =  657506381 *
// *Baskets :    33412 : Basket Size=      32000 bytes  Compression=   1.21     *
// *............................................................................*
// *Br   37 :jtDiscDeepFlavourC : jtDiscDeepFlavourC[nref]/F                    *
// *Entries : 56563000 : Total  Size=  799144245 bytes  File Size  =  641342263 *
// *Baskets :    33400 : Basket Size=      32000 bytes  Compression=   1.25     *
// *............................................................................*
// *Br   38 :jtDiscProb : jtDiscProb[nref]/F                                    *
// *Entries : 56563000 : Total  Size=  798762059 bytes  File Size  =  608438447 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   1.31     *
// *............................................................................*
// *Br   39 :nsvtx     : nsvtx[nref]/I                                          *
// *Entries : 56563000 : Total  Size=  798600667 bytes  File Size  =  192825811 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   4.14     *
// *............................................................................*
// *Br   40 :svtxntrk  : vector<vector<int> >                                   *
// *Entries : 56563000 : Total  Size= 1951277850 bytes  File Size  =  384155870 *
// *Baskets :    67292 : Basket Size=      32000 bytes  Compression=   5.08     *
// *............................................................................*
// *Br   41 :svtxdls   : vector<vector<float> >                                 *
// *Entries : 56563000 : Total  Size= 1951210455 bytes  File Size  =  486279819 *
// *Baskets :    67291 : Basket Size=      32000 bytes  Compression=   4.01     *
// *............................................................................*
// *Br   42 :svtxdls2d : vector<vector<float> >                                 *
// *Entries : 56563000 : Total  Size= 1487749330 bytes  File Size  =  479678373 *
// *Baskets :    53704 : Basket Size=      32000 bytes  Compression=   3.10     *
// *............................................................................*
// *Br   43 :svtxm     : vector<vector<float> >                                 *
// *Entries : 56563000 : Total  Size= 1951075768 bytes  File Size  =  487516056 *
// *Baskets :    67290 : Basket Size=      32000 bytes  Compression=   4.00     *
// *............................................................................*
// *Br   44 :svtxpt    : vector<vector<float> >                                 *
// *Entries : 56563000 : Total  Size= 1951143160 bytes  File Size  =  488290547 *
// *Baskets :    67291 : Basket Size=      32000 bytes  Compression=   3.99     *
// *............................................................................*
// *Br   45 :svtxmcorr : vector<vector<float> >                                 *
// *Entries : 56563000 : Total  Size= 1951345146 bytes  File Size  =  488234897 *
// *Baskets :    67292 : Basket Size=      32000 bytes  Compression=   3.99     *
// *............................................................................*
// *Br   46 :refpt     : refpt[nref]/F                                          *
// *Entries : 56563000 : Total  Size=  798600674 bytes  File Size  =  646027007 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   1.24     *
// *............................................................................*
// *Br   47 :refeta    : refeta[nref]/F                                         *
// *Entries : 56563000 : Total  Size=  798632951 bytes  File Size  =  662599112 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   1.20     *
// *............................................................................*
// *Br   48 :refphi    : refphi[nref]/F                                         *
// *Entries : 56563000 : Total  Size=  798632951 bytes  File Size  =  659986450 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   1.21     *
// *............................................................................*
// *Br   49 :refdphijt : refdphijt[nref]/F                                      *
// *Entries : 56563000 : Total  Size=  798729782 bytes  File Size  =  667232408 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   1.20     *
// *............................................................................*
// *Br   50 :refdrjt   : refdrjt[nref]/F                                        *
// *Entries : 56563000 : Total  Size=  798665228 bytes  File Size  =  648167944 *
// *Baskets :    32273 : Basket Size=      32000 bytes  Compression=   1.23     *
// *............................................................................*
// *Br   51 :refparton_pt : refparton_pt[nref]/F                                *
// *Entries : 56563000 : Total  Size=  798921669 bytes  File Size  =  442588237 *
// *Baskets :    33187 : Basket Size=      32000 bytes  Compression=   1.80     *
// *............................................................................*
// *Br   52 :refparton_flavor : refparton_flavor[nref]/I                        *
// *Entries : 56563000 : Total  Size=  799077430 bytes  File Size  =  259336961 *
// *Baskets :    33400 : Basket Size=      32000 bytes  Compression=   3.08     *
// *............................................................................*
// *Br   53 :refIsHardest : refIsHardest[nref]/O                                *
// *Entries : 56563000 : Total  Size=  370637272 bytes  File Size  =  168943721 *
// *Baskets :    20004 : Basket Size=      32000 bytes  Compression=   2.19     *
// *............................................................................*
// *Br   54 :ngen      : ngen/I                                                 *
// *Entries : 56563000 : Total  Size=  227063122 bytes  File Size  =   41142287 *
// *Baskets :     9214 : Basket Size=      32000 bytes  Compression=   5.51     *
// *............................................................................*
// *Br   55 :genmatchindex : genmatchindex[ngen]/I                              *
// *Entries : 56563000 : Total  Size= 1030006637 bytes  File Size  =  295582124 *
// *Baskets :    40183 : Basket Size=      32000 bytes  Compression=   3.48     *
// *............................................................................*
// *Br   56 :genpt     : genpt[ngen]/F                                          *
// *Entries : 56563000 : Total  Size= 1029684954 bytes  File Size  =  874836318 *
// *Baskets :    40181 : Basket Size=      32000 bytes  Compression=   1.18     *
// *............................................................................*
// *Br   57 :geneta    : geneta[ngen]/F                                         *
// *Entries : 56563000 : Total  Size= 1029725139 bytes  File Size  =  898478795 *
// *Baskets :    40181 : Basket Size=      32000 bytes  Compression=   1.15     *
// *............................................................................*
// *Br   58 :genphi    : genphi[ngen]/F                                         *
// *Entries : 56563000 : Total  Size= 1029725139 bytes  File Size  =  894544767 *
// *Baskets :    40181 : Basket Size=      32000 bytes  Compression=   1.15     *
// *............................................................................*
// *Br   59 :npar      : npar/I                                                 *
// *Entries : 56563000 : Total  Size=  227063122 bytes  File Size  =   42201045 *
// *Baskets :     9214 : Basket Size=      32000 bytes  Compression=   5.38     *
// *............................................................................*
// *Br   60 :parpt     : parpt[npar]/F                                          *
// *Entries : 56563000 : Total  Size= 1093495113 bytes  File Size  =  933861708 *
// *Baskets :    41632 : Basket Size=      32000 bytes  Compression=   1.17     *
// *............................................................................*
// *Br   61 :pareta    : pareta[npar]/F                                         *
// *Entries : 56563000 : Total  Size= 1093536749 bytes  File Size  =  960544192 *
// *Baskets :    41632 : Basket Size=      32000 bytes  Compression=   1.14     *
// *............................................................................*
// *Br   62 :parphi    : parphi[npar]/F                                         *
// *Entries : 56563000 : Total  Size= 1093536749 bytes  File Size  =  956266806 *
// *Baskets :    41632 : Basket Size=      32000 bytes  Compression=   1.14     *
// *............................................................................*
// *Br   63 :parNb     : parNb[npar]/I                                          *
// *Entries : 56563000 : Total  Size= 1093495106 bytes  File Size  =  161091597 *
// *Baskets :    41632 : Basket Size=      32000 bytes  Compression=   6.78     *
// *............................................................................*
// *Br   64 :parNc     : parNc[npar]/I                                          *
// *Entries : 56563000 : Total  Size= 1093495106 bytes  File Size  =  181735412 *
// *Baskets :    41632 : Basket Size=      32000 bytes  Compression=   6.01     *
// *............................................................................*
// *Br   65 :parHasGSPB : parHasGSPB[npar]/O                                    *
// *Entries : 56563000 : Total  Size=  444360946 bytes  File Size  =  147655489 *
// *Baskets :    22622 : Basket Size=      32000 bytes  Compression=   3.01     *
// *............................................................................*
// *Br   66 :parHasGSPC : parHasGSPC[npar]/O                                    *
// *Entries : 56563000 : Total  Size=  444360946 bytes  File Size  =  159687481 *
// *Baskets :    22622 : Basket Size=      32000 bytes  Compression=   2.78     *
// *............................................................................*
// *Br   67 :genIsHardest : genIsHardest[ngen]/O                                *
// *Entries : 56563000 : Total  Size=  428366333 bytes  File Size  =  195192232 *
// *Baskets :    21444 : Basket Size=      32000 bytes  Compression=   2.19     *
// *............................................................................*
// *Br   68 :gsjt1Pt   : gsjt1Pt[ngen]/F                                        *
// *Entries : 56563000 : Total  Size= 1029765324 bytes  File Size  =  877388905 *
// *Baskets :    40181 : Basket Size=      32000 bytes  Compression=   1.17     *
// *............................................................................*
// *Br   69 :gsjt1Eta  : gsjt1Eta[ngen]/F                                       *
// *Entries : 56563000 : Total  Size= 1029805609 bytes  File Size  =  897891690 *
// *Baskets :    40182 : Basket Size=      32000 bytes  Compression=   1.15     *
// *............................................................................*
// *Br   70 :gsjt1Phi  : gsjt1Phi[ngen]/F                                       *
// *Entries : 56563000 : Total  Size= 1029805609 bytes  File Size  =  893676695 *
// *Baskets :    40182 : Basket Size=      32000 bytes  Compression=   1.15     *
// *............................................................................*
// *Br   71 :gsjt2Pt   : gsjt2Pt[ngen]/F                                        *
// *Entries : 56563000 : Total  Size= 1029765324 bytes  File Size  =  877650731 *
// *Baskets :    40181 : Basket Size=      32000 bytes  Compression=   1.17     *
// *............................................................................*
// *Br   72 :gsjt2Eta  : gsjt2Eta[ngen]/F                                       *
// *Entries : 56563000 : Total  Size= 1029805609 bytes  File Size  =  896810482 *
// *Baskets :    40182 : Basket Size=      32000 bytes  Compression=   1.15     *
// *............................................................................*
// *Br   73 :gsjt2Phi  : gsjt2Phi[ngen]/F                                       *
// *Entries : 56563000 : Total  Size= 1029805609 bytes  File Size  =  892641554 *
// *Baskets :    40182 : Basket Size=      32000 bytes  Compression=   1.15     *
// *............................................................................*
// *Br   74 :psjt1Pt   : psjt1Pt[ngen]/F                                        *
// *Entries : 56563000 : Total  Size= 1029765324 bytes  File Size  =  867003787 *
// *Baskets :    40181 : Basket Size=      32000 bytes  Compression=   1.19     *
// *............................................................................*
// *Br   75 :psjt1Eta  : psjt1Eta[ngen]/F                                       *
// *Entries : 56563000 : Total  Size= 1029805609 bytes  File Size  =  889730539 *
// *Baskets :    40182 : Basket Size=      32000 bytes  Compression=   1.16     *
// *............................................................................*
// *Br   76 :psjt1Phi  : psjt1Phi[ngen]/F                                       *
// *Entries : 56563000 : Total  Size= 1029805609 bytes  File Size  =  885607133 *
// *Baskets :    40182 : Basket Size=      32000 bytes  Compression=   1.16     *
// *............................................................................*
// *Br   77 :psjt2Pt   : psjt2Pt[ngen]/F                                        *
// *Entries : 56563000 : Total  Size= 1029765324 bytes  File Size  =  771488213 *
// *Baskets :    40181 : Basket Size=      32000 bytes  Compression=   1.33     *
// *............................................................................*
// *Br   78 :psjt2Eta  : psjt2Eta[ngen]/F                                       *
// *Entries : 56563000 : Total  Size= 1029805609 bytes  File Size  =  785853616 *
// *Baskets :    40182 : Basket Size=      32000 bytes  Compression=   1.31     *
// *............................................................................*
// *Br   79 :psjt2Phi  : psjt2Phi[ngen]/F                                       *
// *Entries : 56563000 : Total  Size= 1029805609 bytes  File Size  =  782780181 *
// *Baskets :    40182 : Basket Size=      32000 bytes  Compression=   1.31     *
// *............................................................................*

// %%
TCanvas *c = new TCanvas();

// %%
t->Draw("parNb");
c->Draw();
// Out:
// <div id="root_plot_9"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
//        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-1.25000009313226,"fY1":-2262598.96857676,"fX2":11.2500000931323,"fY2":20363389.3685768,"fXtoAbsPixelk":69.6000541484835,"fXtoPixelk":69.6000541484835,"fXtoPixel":55.6799991703033,"fYtoAbsPixelk":424.800047186661,"fYtoPixelk":424.800047186661,"fYtoPixel":-2.08609671748545e-5,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-1.25000009313226,"fPixeltoXk":-1.25000009313226,"fPixeltoX":0.017959770382564,"fAbsPixeltoYk":20363389.3685768,"fPixeltoYk":-2262598.96857676,"fPixeltoY":-47936.4159685456,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":10,"fUymax":18100790.4,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":10,"fY2":18100790.4,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":50331657,"fName":"htemp","fTitle":"parNb","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":7,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":54525952,"fName":"xaxis","fTitle":"parNb","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":5,"fXmin":0,"fXmax":10,"fXbins":[],"fFirst":1,"fLast":100,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":215801107,"fTsumw":215801107,"fTsumw2":215801107,"fTsumwx":6422906,"fTsumwx2":7781336,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPaveStats","fUniqueID":0,"fBits":50331657,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":8.50000025331975,"fY1":15272542.1275786,"fX2":11.0000003278256,"fY2":18892700.1806063,"fX1NDC":0.780000016093254,"fY1NDC":0.775000005960464,"fX2NDC":0.980000019073486,"fY2NDC":0.935000002384186,"fBorderSize":1,"fInit":1,"fShadowColor":1,"fCornerRadius":0,"fOption":"brNDC","fName":"stats","fTex ...

// %%
Float_t psjt1Pt[30];
t->SetBranchAddress("psjt1Pt", psjt1Pt);

Float_t psjt2Pt[30];
t->SetBranchAddress("psjt2Pt", psjt2Pt);

Float_t genpt[30];
t->SetBranchAddress("genpt", genpt);

Float_t jtpt[30];
t->SetBranchAddress("jtpt", jtpt);

Int_t ngen;
t->SetBranchAddress("ngen", &ngen);

Int_t nref;
t->SetBranchAddress("nref", &nref);

Int_t *genmatchindex[30];
t->SetBranchAddress("genmatchindex", genmatchindex);

Long64_t nentries = t->GetEntries();

// %%
TH1F *hpt = new TH1F();

// %%
TH1F *hpt2 = new TH1F();

// %%
TCanvas *c = new TCanvas("c", "", 500, 500);

// %%
t->SetBranchStatus("*", 0);
t->SetBranchStatus("ngen", 1);
t->SetBranchStatus("nref", 1);
t->SetBranchStatus("psjt1Pt", 1);
t->SetBranchStatus("psjt2Pt", 1);
t->SetBranchStatus("jtpt", 1);
t->SetBranchStatus("genpt", 1);

// %%
hpt = new TH1F("h", "", 100, 0, 100);
hpt2 = new TH1F("h2", "", 100, 0, 100);
for (Long64_t i = 0; i < nentries; i++) {
    t->GetEntry(i);
    if (i%1000000 == 0) {std::cout << "i = " << i << endl;}
    for (Int_t j = 0; j < ngen; j++) {
        if (psjt2Pt[j] > psjt1Pt[j]) { 
            std::cout << "psjt2Pt > psjt1Pt" << endl;}
    }
}
// Out:
// i = 0
// i = 1000000
// i = 2000000
// i = 3000000
// i = 4000000
// i = 5000000
// i = 6000000
// i = 7000000
// i = 8000000
// i = 9000000
// i = 10000000
// i = 11000000
// i = 12000000
// i = 13000000
// i = 14000000
// i = 15000000
// i = 16000000
// i = 17000000
// i = 18000000
// i = 19000000
// i = 20000000
// i = 21000000
// i = 22000000
// i = 23000000
// i = 24000000
// i = 25000000
// i = 26000000
// i = 27000000
// i = 28000000
// i = 29000000
// i = 30000000
// i = 31000000
// i = 32000000
// i = 33000000
// i = 34000000
// i = 35000000
// i = 36000000
// i = 37000000
// i = 38000000
// i = 39000000
// i = 40000000
// i = 41000000
// i = 42000000
// i = 43000000
// i = 44000000
// i = 45000000
// i = 46000000
// i = 47000000
// i = 48000000
// i = 49000000
// i = 50000000
// i = 51000000
// i = 52000000
// i = 53000000
// i = 54000000
// i = 55000000
// i = 56000000

// %%
hpt->SetXTitle("pt");
hpt->Draw();
c->Draw();
// Out:
// <div id="root_plot_1"
//      style="width: 496px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
//        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-12.5000009313226,"fY1":-0.131250009778888,"fX2":112.500000931323,"fY2":1.18125000977889,"fXtoAbsPixelk":49.6000529563905,"fXtoPixelk":49.6000529563905,"fXtoPixel":3.96799994087219,"fYtoAbsPixelk":424.800047186661,"fYtoPixelk":424.800047186661,"fYtoPixel":-359.619042260306,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":496,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":-12.5000009313226,"fPixeltoXk":-12.5000009313226,"fPixeltoX":0.252016132787591,"fAbsPixeltoYk":1.18125000977889,"fPixeltoYk":-0.131250009778888,"fPixeltoY":-0.00278072038041902,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":100,"fUymax":1.05,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0,"fY1":0,"fX2":100,"fY2":1.05,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":50331656,"fName":"h","fTitle":"","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":102,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"xaxis","fTitle":"pt","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":100,"fXmin":0,"fXmax":100,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":0,"fTsumw":0,"fTsumw2":0,"fTsumwx":0,"fTsumwx2":0,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPaveStats","fUniqueID":0,"fBits":50331657,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":85.0000025331975,"fY1":0.885937513201498,"fX2":110.000003278256,"fY2":1.09593751163688,"fX1NDC":0.780000016093254,"fY1NDC":0.775000005960464,"fX2NDC":0.980000019073486,"fY2NDC":0.935000002384186,"fBorderSize":1,"fInit":1,"fShadowColor":1,"fCornerRadius":0,"fOption":"brNDC","fName":"stats","fTextAngle":0,"fTextSize":0,"fTextAlign":12,"fTextColor" ...

// %% [markdown]
// ## Functions

// %% [markdown]
// plot_zg() [includes qcdMC and bJetMC]

// %%
// This functions creates histograms for the substructure variables zg and Rg
// at parton level

#include <iostream>
#include "stdio.h"
#include "TFile.h"
#include "TH2.h"
#include "TTree.h"
#include <vector>

void plot_zg_rg() 
{
    const int n = 2;
    
    std::string path_incl = "/data_CMS/cms/mnguyen//bJet2022/qcdMC/SD/merged_HiForestAOD.root";
    std::string path_bJet = "/data_CMS/cms/mnguyen//bJet2022/bJetMC/SD/merged_HiForestAOD.root";
    std::string fnames[n] = {path_incl, path_bJet};
    
    std::string h_incl = "h_incl";
    std::string h_bJet = "h_bJet";
    std::string hnames[n] = {h_incl, h_bJet};
    
    
    // zg histograms
    TH2F *hs_zg[n];
    
    // Rg histograms
    TH2F *hs_rg[n];
    

    for (int ni = 0; ni < n; ni++) {
        
        auto finname = fnames[ni];
        auto hname = hnames[ni];

        std::cout << "\nReading from " << finname << endl;
        TFile *fin = new TFile(finname.c_str());
        TTree *t = (TTree *) fin->Get("ak4PFJetAnalyzer/t");
        TTree *HiTree = (TTree *) fin->Get("hiEvtAnalyzer/HiTree");

        //Declaration of leaves types

        // For JetAnalyzer tree
        Int_t           nref;
        Float_t         rawpt[30];
        Float_t         jtpt[30];
        Float_t         jteta[30];
        Float_t         jtphi[30];
        Float_t         jtHadFlav[30];
        Float_t         jtParFlav[30];
        Int_t           jtNbHad[30];
        Int_t           jtNcHad[30];
        Int_t           jtNbPar[30];
        Int_t           jtNcPar[30];
        Bool_t          jtHasGSPB[30];
        Bool_t          jtHasGSPC[30];
        Bool_t          jtIsHardest[30];
        Float_t         sjt1Pt[30];
        Float_t         sjt1Eta[30];
        Float_t         sjt1Phi[30];
        Float_t         sjt1HadFlav[30];
        Float_t         sjt1ParFlav[30];
        Float_t         sjt2Pt[30];
        Float_t         sjt2Eta[30];
        Float_t         sjt2Phi[30];
        Float_t         sjt2HadFlav[30];
        Float_t         sjt2ParFlav[30];
        Float_t         rsjt1Pt[30]; //ref
        Float_t         rsjt1Eta[30];
        Float_t         rsjt1Phi[30];
        Float_t         rsjt2Pt[30];
        Float_t         rsjt2Eta[30];
        Float_t         rsjt2Phi[30];
        Float_t         jtDiscCSVV2[30];
        Float_t         jtDiscDeepCSVB[30];
        Float_t         jtDiscDeepCSVBB[30];
        Float_t         jtDiscDeepCSVC[30];
        Float_t         jtDiscDeepFlavourB[30];
        Float_t         jtDiscDeepFlavourBB[30];
        Float_t         jtDiscDeepFlavourLEPB[30];
        Float_t         jtDiscDeepFlavourC[30];
        Float_t         jtDiscProb[30];
        Int_t           nsvtx[30];
        vector<vector<int> > svtxntrk;
        vector<vector<float> > svtxdls;
        vector<vector<float> > svtxdls2d;
        vector<vector<float> > svtxm;
        vector<vector<float> > svtxpt;
        vector<vector<float> > svtxmcorr;
        Float_t         refpt[30];
        Float_t         refeta[30];
        Float_t         refphi[30];
        Float_t         refdphijt[30];
        Float_t         refdrjt[30];
        Float_t         refparton_pt[30];
        Int_t           refparton_flavor[30];
        Bool_t          refIsHardest[30];
        Int_t           ngen;
        Int_t           genmatchindex[30];
        Float_t         genpt[30];
        Float_t         geneta[30];
        Float_t         genphi[30];
        Int_t           npar;
        Float_t         parpt[30];
        Float_t         pareta[30];
        Float_t         parphi[30];
        Int_t           parNb[30];
        Int_t           parNc[30];
        Bool_t          parHasGSPB[30];
        Bool_t          parHasGSPC[30];
        Bool_t          genIsHardest[30];
        Float_t         gsjt1Pt[30];
        Float_t         gsjt1Eta[30];
        Float_t         gsjt1Phi[30];
        Float_t         gsjt2Pt[30];
        Float_t         gsjt2Eta[30];
        Float_t         gsjt2Phi[30];
        Float_t         psjt1Pt[30];
        Float_t         psjt1Eta[30];
        Float_t         psjt1Phi[30];
        Float_t         psjt2Pt[30];
        Float_t         psjt2Eta[30];
        Float_t         psjt2Phi[30];

        // For EvtAnalyzer tree
        UInt_t          run;
        ULong64_t       evt;
        UInt_t          lumi;
        Float_t         vx;
        Float_t         vy;
        Float_t         vz;
        Float_t         pthat;
        Float_t         weight;    

        // Set branch addresses

        // For JetAnalyzer tree
        t->SetBranchAddress("nref", &nref);
        t->SetBranchAddress("rawpt", rawpt);
        t->SetBranchAddress("jtpt", jtpt);
        t->SetBranchAddress("jteta", jteta);
        t->SetBranchAddress("jtphi", jtphi);
        t->SetBranchAddress("jtHadFlav", jtHadFlav);
        t->SetBranchAddress("jtParFlav", jtParFlav);
        t->SetBranchAddress("jtNbHad", jtNbHad);
        t->SetBranchAddress("jtNcHad", jtNcHad);
        t->SetBranchAddress("jtNbPar", jtNbPar);
        t->SetBranchAddress("jtNcPar", jtNcPar);
        t->SetBranchAddress("jtHasGSPB", jtHasGSPB);
        t->SetBranchAddress("jtHasGSPC", jtHasGSPC);
        t->SetBranchAddress("jtIsHardest", jtIsHardest);
        t->SetBranchAddress("sjt1Pt", sjt1Pt);
        t->SetBranchAddress("sjt1Eta", sjt1Eta);
        t->SetBranchAddress("sjt1Phi", sjt1Phi);
        t->SetBranchAddress("sjt1HadFlav", sjt1HadFlav);
        t->SetBranchAddress("sjt1ParFlav", sjt1ParFlav);
        t->SetBranchAddress("sjt2Pt", sjt2Pt);
        t->SetBranchAddress("sjt2Eta", sjt2Eta);
        t->SetBranchAddress("sjt2Phi", sjt2Phi);
        t->SetBranchAddress("sjt2HadFlav", sjt2HadFlav);
        t->SetBranchAddress("sjt2ParFlav", sjt2ParFlav);
        t->SetBranchAddress("rsjt1Pt", rsjt1Pt);
        t->SetBranchAddress("rsjt1Eta", rsjt1Eta);
        t->SetBranchAddress("rsjt1Phi", rsjt1Phi);
        t->SetBranchAddress("rsjt2Pt", rsjt2Pt);
        t->SetBranchAddress("rsjt2Eta", rsjt2Eta);
        t->SetBranchAddress("rsjt2Phi", rsjt2Phi);
        t->SetBranchAddress("jtDiscCSVV2", jtDiscCSVV2);
        t->SetBranchAddress("jtDiscDeepCSVB", jtDiscDeepCSVB);
        t->SetBranchAddress("jtDiscDeepCSVBB", jtDiscDeepCSVBB);
        t->SetBranchAddress("jtDiscDeepCSVC", jtDiscDeepCSVC);
        t->SetBranchAddress("jtDiscDeepFlavourB", jtDiscDeepFlavourB);
        t->SetBranchAddress("jtDiscDeepFlavourBB", jtDiscDeepFlavourBB);
        t->SetBranchAddress("jtDiscDeepFlavourLEPB", jtDiscDeepFlavourLEPB);
        t->SetBranchAddress("jtDiscDeepFlavourC", jtDiscDeepFlavourC);
        t->SetBranchAddress("jtDiscProb", jtDiscProb);
        t->SetBranchAddress("nsvtx", nsvtx);
        /*
        t->SetBranchAddress("svtxntrk", &svtxntrk);
        t->SetBranchAddress("svtxdls", &svtxdls);
        t->SetBranchAddress("svtxdls2d", &svtxdls2d);
        t->SetBranchAddress("svtxm", &svtxm);
        t->SetBranchAddress("svtxpt", &svtxpt);
        t->SetBranchAddress("svtxmcorr", &svtxmcorr);
        */
        t->SetBranchAddress("refpt", refpt);
        t->SetBranchAddress("refeta", refeta);
        t->SetBranchAddress("refphi", refphi);
        t->SetBranchAddress("refdphijt", refdphijt);
        t->SetBranchAddress("refdrjt", refdrjt);
        t->SetBranchAddress("refparton_pt", refparton_pt);
        t->SetBranchAddress("refparton_flavor", refparton_flavor);
        t->SetBranchAddress("refIsHardest", refIsHardest);
        t->SetBranchAddress("ngen", &ngen);
        t->SetBranchAddress("genmatchindex", genmatchindex);
        t->SetBranchAddress("genpt", genpt);
        t->SetBranchAddress("geneta", geneta);
        t->SetBranchAddress("genphi", genphi);
        t->SetBranchAddress("npar", &npar);
        t->SetBranchAddress("parpt", parpt);
        t->SetBranchAddress("pareta", pareta);
        t->SetBranchAddress("parphi", parphi);
        t->SetBranchAddress("parNb", parNb);
        t->SetBranchAddress("parNc", parNc);
        t->SetBranchAddress("parHasGSPB", parHasGSPB);
        t->SetBranchAddress("parHasGSPC", parHasGSPC);
        t->SetBranchAddress("genIsHardest", genIsHardest);
        t->SetBranchAddress("gsjt1Pt", gsjt1Pt);
        t->SetBranchAddress("gsjt1Eta", gsjt1Eta);
        t->SetBranchAddress("gsjt1Phi", gsjt1Phi);
        t->SetBranchAddress("gsjt2Pt", gsjt2Pt);
        t->SetBranchAddress("gsjt2Eta", gsjt2Eta);
        t->SetBranchAddress("gsjt2Phi", gsjt2Phi);
        t->SetBranchAddress("psjt1Pt", psjt1Pt);
        t->SetBranchAddress("psjt1Eta", psjt1Eta);
        t->SetBranchAddress("psjt1Phi", psjt1Phi);
        t->SetBranchAddress("psjt2Pt", psjt2Pt);
        t->SetBranchAddress("psjt2Eta", psjt2Eta);
        t->SetBranchAddress("psjt2Phi", psjt2Phi);

        // For EvtAnalyzer tree
        HiTree->SetBranchAddress("run", &run);
        HiTree->SetBranchAddress("evt", &evt);
        HiTree->SetBranchAddress("lumi", &lumi);
        HiTree->SetBranchAddress("vx", &vx);
        HiTree->SetBranchAddress("vy", &vy);
        HiTree->SetBranchAddress("vz", &vz);
        HiTree->SetBranchAddress("pthat", &pthat);
        HiTree->SetBranchAddress("weight", &weight);

        // Activate specific branches
        t->SetBranchStatus("*", 0);
        for (auto activeBranchName : {"nref", "rsjt1Pt", "rsjt1Eta", "rsjt1Phi", 
                                      "rsjt2Pt", "rsjt2Eta", "rsjt2Phi", "refpt"}) {
            //std::cout << "Activating branch " << activeBranchName << endl;
            t->SetBranchStatus(activeBranchName, 1);
        }
        HiTree->SetBranchStatus("*", 0);
        HiTree->SetBranchStatus("weight", 1);

        // Create the new histograms
        
        // X = zg, Y = parpt
        TH2F *h_zg = new TH2F((hname + "_zg").c_str(), "refpt vs zg", 20, 0.01, 0.6, 20, 50, 100);
        
        // X = Rg, Y = parpt
        TH2F *h_rg = new TH2F((hname + "_rg").c_str(), "refpt vs rg", 20, 0.01, 1., 20, 50, 100);
        //TH1F *test = new TH1F("test", "test rg", 20, 0.01, 4);

        Long64_t nentries = t->GetEntries();

        std::cout << "Creating histograms..." << endl;
        
        for (Long64_t i = 0; i < nentries; i++) {
            t->GetEntry(i);
            HiTree->GetEntry(i);

            // Print progress
            if (i%1000000 == 0) {
                std::cout << "i = " << i << endl;
            }
            
            // Calculate zg, Rg
            for (Long64_t j = 0; j < nref; j++)  {
                Float_t zg = 0.;
                Float_t rg = 0.;
                Float_t minpt = min(rsjt1Pt[j], rsjt2Pt[j]);
                if (minpt > 0.) {
                    zg = minpt / (rsjt2Pt[j]+rsjt1Pt[j]);
                    Float_t deta = rsjt1Eta[j] - rsjt2Eta[j];
                    Float_t dphi = acos(cos(rsjt1Phi[j] - rsjt2Phi[j]));
                    rg = sqrt(deta * deta + dphi * dphi);
                }
                // Fill histograms
                h_zg->Fill(zg, refpt[j], weight);
                h_rg->Fill(rg, refpt[j], weight);
            }
        }
        hs_zg[ni] = h_zg;
        hs_rg[ni] = h_rg;
    }       
    std::string foutname = "ref_sub.root";
    std::cout << "\n(Re)creating file " << foutname << endl;
    TFile *fout = new TFile(foutname.c_str(),  "recreate");
    std::cout << "Saving histograms." << endl;
    for (TH2F *h : hs_zg) h->Write();
    for (TH2F *h : hs_rg) h->Write();
    fout->Close();
}

// %% [markdown]
// draw_zg()

// %%
// This function draws the histograms included in the zg.root file
// and saves the image as a PNG file

#include <iostream>
#include "stdio.h"
#include "TFile.h"
#include "TH2.h"
#include "TTree.h"
#include <vector>

void draw_zg_rg() 
{
    const int n = 2;
    // General 
    gStyle->SetLegendTextSize(0.04);
    
    // Use to hide the title
    //gStyle->SetOptTitle(0);
    
    // Load data
    TFile *fin = new TFile("gen_sub.root");
    TH2F *hs_zg[n] = {(TH2F *) fin->Get("h_incl_zg"), (TH2F *) fin->Get("h_bJet_zg")};
    TH2F *hs_rg[n] = {(TH2F *) fin->Get("h_incl_rg"), (TH2F *) fin->Get("h_bJet_rg")};
    
    // zg histograms    
      
    // 2D histograms
    TCanvas *czg = new TCanvas("czg", "genpt vs zg", 600, 400);  
    //czg->SetCanvasSize(1000, 1000);
    //czg->SetLeftMargin(0.5);
    czg->Divide(2, 1);
    
    czg->cd(1);
    hs_zg[0]->SetTitle("qcdMC");
    hs_zg[0]->SetStats(0);
    hs_zg[0]->SetXTitle("z_{g}");
    hs_zg[0]->SetYTitle("genpt");
    hs_zg[0]->GetYaxis()->SetTitleOffset(2.0);
    hs_zg[0]->SetStats(0);
    
    hs_zg[0]->Draw("COLZ");

    czg->cd(2);
    hs_zg[1]->SetTitle("bJetMC");
    hs_zg[1]->SetXTitle("z_{g}");
    hs_zg[1]->SetYTitle("genpt"); 
    hs_zg[1]->SetStats(0);
    hs_zg[1]->SetTitle("bJet");
    
    hs_zg[1]->Draw("COLZ");

    
    czg->Draw();
    czg->Print("genptVSzg.jpg", "jpg");
    
    // Projection histograms
    TCanvas *cproj_zg = new TCanvas("cproj_zg", "sum genpt vs zg", 600, 400); 
    TH1F *hsproj_zg[n] = {(TH1F *) hs_zg[0]->ProjectionX("hproj_incl", 1, 20), 
                       (TH1F *) hs_zg[1]->ProjectionX("hproj_bJet", 1, 20)};
    
    // Scale by bin width and total counts
    for (int i = 0; i < n; i++) {
        hsproj_zg[i]->Scale(1/(hsproj_zg[i]->Integral())); // it's not total, it's all the counts in the histo
        hsproj_zg[i]->Scale(1/(hsproj_zg[i]->GetXaxis()->GetBinWidth(0)));
    }
       
    hsproj_zg[0]->SetMarkerStyle(kFullCircle);
    hsproj_zg[0]->SetStats(0);
    hsproj_zg[0]->SetTitle("qcdMC");
    hsproj_zg[0]->SetXTitle("z_{g}");
    hsproj_zg[0]->SetYTitle("1/N dN/dz_{g} for genpt in [50, 100] GeV");
    
    hsproj_zg[1]->SetMarkerStyle(kFullSquare);
    hsproj_zg[1]->SetMarkerColor(2);
    hsproj_zg[1]->SetTitle("bJetMC");
    
    hsproj_zg[0]->Draw("E");
    hsproj_zg[1]->Draw("SAME E");
    
    gPad->BuildLegend();
    hsproj_zg[0]->SetTitle("Projection");
    
    cproj_zg->Draw();
    cproj_zg->Print("zg_proj_gen.jpg", "jpg");
    
    // Rg histograms
    
    // 2D histograms
    
    TCanvas *crg = new TCanvas("crg", "genpt vs rg", 600, 400);   
    //crg->SetLeftMargin(0.2);
    crg->Divide(2, 1, 0.02);
    
    crg->cd(1);
    hs_rg[0]->SetTitle("qcdMC");
    hs_rg[0]->SetStats(0);
    hs_rg[0]->SetXTitle("R_{g}");
    hs_rg[0]->SetYTitle("genpt");
    hs_rg[0]->SetStats(0);
    
    hs_rg[0]->Draw("COLZ");

    crg->cd(2);
    hs_rg[1]->SetTitle("bJetMC");
    hs_rg[1]->SetXTitle("R_{g}");
    hs_rg[1]->SetYTitle("genpt"); 
    hs_rg[1]->SetStats(0);
    hs_rg[1]->SetTitle("bJetMC");
    
    hs_rg[1]->Draw("COLZ");

    crg->Draw();
    crg->Print("genptVSrg.jpg", "jpg");
    
    // Rg Projection
    TCanvas *cproj_rg = new TCanvas("cproj_rg", "sum genpt vs rg", 600, 400); 
    TH1F *hsproj_rg[n] = {(TH1F *) hs_rg[0]->ProjectionX("hproj_incl", 1, 20), 
                       (TH1F *) hs_rg[1]->ProjectionX("hproj_bJet", 1, 20)};
    
    // Scale by bin width and total counts
    for (int i = 0; i < n; i++) {
        hsproj_rg[i]->Scale(1/(hsproj_rg[i]->Integral())); // it's not total, it's all the counts in the histo
        hsproj_rg[i]->Scale(1/(hsproj_rg[i]->GetXaxis()->GetBinWidth(0)));
    }
       
    hsproj_rg[0]->SetMarkerStyle(kFullCircle);
    hsproj_rg[0]->SetStats(0);
    hsproj_rg[0]->SetTitle("qcdMC");
    hsproj_rg[0]->SetXTitle("R_{g}");
    hsproj_rg[0]->SetYTitle("1/N dN/dR_{g} for genpt in [50, 100] GeV");
    
    hsproj_rg[1]->SetMarkerStyle(kFullSquare);
    hsproj_rg[1]->SetMarkerColor(2);
    hsproj_rg[1]->SetTitle("bJetMC");
    
    hsproj_rg[0]->Draw("E");
    hsproj_rg[1]->Draw("SAME E");
    
    gPad->BuildLegend();
    hsproj_rg[0]->SetTitle("Projection");
    
    cproj_rg->Draw();
    cproj_rg->Print("rg_proj_gen.png", "png");
    
}

// %% [markdown]
// ## Tests

// %%
plot_zg_rg();
// Out:
// Reading from /data_CMS/cms/mnguyen//bJet2022/qcdMC/SD/merged_HiForestAOD.root
// Creating histograms...
// i = 0
// i = 1000000
// i = 2000000
// i = 3000000
// i = 4000000
// i = 5000000
// i = 6000000
// i = 7000000
// i = 8000000
// i = 9000000
// i = 10000000
// i = 11000000
// i = 12000000
// i = 13000000
// i = 14000000
// i = 15000000
// i = 16000000
// i = 17000000
// i = 18000000
// i = 19000000
// i = 20000000
// i = 21000000
// i = 22000000
// i = 23000000
// i = 24000000
// i = 25000000
// i = 26000000
// i = 27000000
// i = 28000000
// i = 29000000
// i = 30000000
// i = 31000000
// i = 32000000
// i = 33000000
// i = 34000000
// i = 35000000
// i = 36000000
// i = 37000000
// i = 38000000
// i = 39000000
// i = 40000000
// i = 41000000
// i = 42000000
// i = 43000000
// i = 44000000
// i = 45000000
// i = 46000000
// i = 47000000
// i = 48000000
// i = 49000000
// i = 50000000
// i = 51000000
// i = 52000000
// i = 53000000
// i = 54000000
// i = 55000000
// i = 56000000
//
// Reading from /data_CMS/cms/mnguyen//bJet2022/bJetMC/SD/merged_HiForestAOD.root
// Creating histograms...
// i = 0
// i = 1000000
// i = 2000000
// i = 3000000
// i = 4000000
// i = 5000000
// i = 6000000
// i = 7000000
// i = 8000000
// i = 9000000
// i = 10000000
// i = 11000000
// i = 12000000
// i = 13000000
//
// (Re)creating file gen_sub.root
// Saving histograms.

// %%
%jsroot on
draw_zg_rg();
//gROOT->GetListOfCanvases()->Draw();
// Out:
// <div id="root_plot_5"
//      style="width: 596px; height: 372px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
//        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":596,"fYtoAbsPixelk":372.00005,"fYtoPixelk":372.00005,"fYtoPixel":-372,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":596,"fVtoAbsPixelk":372.00005,"fVtoPixelk":372,"fVtoPixel":-372,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00167785234899329,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00268817204301075,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":50331657,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.0637500054948035,"fY1":43.7499995343387,"fX2":0.673750005494803,"fY2":106.250000465661,"fXtoAbsPixelk":30.6890008053287,"fXtoPixelk":24.7290009385451,"fXtoPixel":387.905079326791,"fYtoAbsPixelk":623.472043680715,"fYtoPixelk":619.752043763864,"fYtoPixel":-5.83295991574287,"fUtoAbsPixelk":5.96004986678362,"fUtoPixelk":5e-5,"fUtoPixel":286.080000266433,"fVtoAbsPixelk":368.280050083148,"fVtoPixelk":364.560000166297,"fVtoPixel":-364.560000166297,"fAbsPixeltoXk":-0.0791145886993524,"fPixeltoXk":-0.0637500054948035,"fPixeltoX":0.0025779502597272,"fAbsPixeltoYk":106.88775556266,"fPixeltoYk":43.7499995343387,"fPixeltoY":-0.171439546035804,"fXlowNDC":0.00999999977648258,"fYlowNDC":0.00999999977648258,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":0.480000000447035,"fHNDC":0.980000000447035,"fAbsXlowNDC":0.00999999977648258,"fAbsYlowNDC":0.00999999977648258,"fAbsWNDC":0.480000000447035,"fAbsHNDC":0.980000000447035,"fUxmin":0.01,"fUymin":50,"fUxmax":0.6,"fUymax":100,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":1,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0.01,"fY1":50,"fX2":0.6,"fY2":100,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH2F","fUniqueID":0,"fBits":50332168,"fName":"h_incl_zg","fTitle":"qcdMC","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":484,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"xaxis","fTitle":"z_{g}","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":20,"fXmin":0.01,"fXmax":0.6,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename ...
// <div id="root_plot_6"
//      style="width: 596px; height: 372px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
//        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.0637500054948035,"fY1":-0.955505315800855,"fX2":0.673750005494803,"fY2":8.59954727268216,"fXtoAbsPixelk":51.5186977406552,"fXtoPixelk":51.5186977406552,"fXtoPixel":808.13558117818,"fYtoAbsPixelk":334.800047782707,"fYtoPixelk":334.800047782707,"fYtoPixel":-38.9322818011889,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":596,"fVtoAbsPixelk":372.00005,"fVtoPixelk":372,"fVtoPixel":-372,"fAbsPixeltoXk":-0.0637500054948035,"fPixeltoXk":-0.0637500054948035,"fPixeltoX":0.00123741612582149,"fAbsPixeltoYk":8.59954727268216,"fPixeltoYk":-0.955505315800855,"fPixeltoY":-0.0256856252378576,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0.01,"fUymin":0,"fUxmax":0.6,"fUymax":7.6440419568813,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0.01,"fY1":0,"fX2":0.6,"fY2":7.6440419568813,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1D","fUniqueID":0,"fBits":50332168,"fName":"hproj_incl","fTitle":"Projection","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":20,"fMarkerSize":1,"fNcells":22,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"xaxis","fTitle":"R_{g}","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":20,"fXmin":0.01,"fXmax":1,"fXbins":[],"fFirst":1,"fLast":20,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"yaxis","fTitle":"1\/N dN\/dR_{g} for genpt in [50, 100] GeV","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":5561221.91050264,"fTsumw":36004.7221649857,"fTsumw2":233.103450831481,"fTsumwx":6280.68557320087,"fTsumwx2":1408.18276361109,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[3.72926420999513e-7,4.9502177216658e-6,1.28803463375166e-5,1.4688656151852e-5,1.27144395633232e-5,1.03339464623335e-5,8.98026401297155e-6,6.15600277810926e-6,2.47038781963356e-6,2.27784793359203e-7,1.00563074412663e-8,1.15902788775854e-10,3.55198321639489e-12,2.04924783964588e-13,0,0,0,0,0,0,0,0],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fBuf ...
// <div id="root_plot_7"
//      style="width: 596px; height: 372px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
//        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":596,"fYtoAbsPixelk":372.00005,"fYtoPixelk":372.00005,"fYtoPixel":-372,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":596,"fVtoAbsPixelk":372.00005,"fVtoPixelk":372,"fVtoPixel":-372,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00167785234899329,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00268817204301075,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":50331657,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.113750009220094,"fY1":43.7499995343387,"fX2":1.12375000922009,"fY2":106.250000465661,"fXtoAbsPixelk":37.120617106247,"fXtoPixelk":25.2006173726798,"fXtoPixel":221.543431472778,"fYtoAbsPixelk":623.472043680715,"fYtoPixelk":619.752043763864,"fYtoPixel":-5.83295991574287,"fUtoAbsPixelk":11.9200497335672,"fUtoPixelk":5e-5,"fUtoPixel":274.160000532866,"fVtoAbsPixelk":368.280050083148,"fVtoPixelk":364.560000166297,"fVtoPixel":-364.560000166297,"fAbsPixeltoXk":-0.167554356540732,"fPixeltoXk":-0.113750009220094,"fPixeltoX":0.00451378762779015,"fAbsPixeltoYk":106.88775556266,"fPixeltoYk":43.7499995343387,"fPixeltoY":-0.171439546035804,"fXlowNDC":0.0199999995529652,"fYlowNDC":0.00999999977648258,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":0.46000000089407,"fHNDC":0.980000000447035,"fAbsXlowNDC":0.0199999995529652,"fAbsYlowNDC":0.00999999977648258,"fAbsWNDC":0.46000000089407,"fAbsHNDC":0.980000000447035,"fUxmin":0.01,"fUymin":50,"fUxmax":1,"fUymax":100,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":1,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0.01,"fY1":50,"fX2":1,"fY2":100,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH2F","fUniqueID":0,"fBits":50332168,"fName":"h_incl_rg","fTitle":"qcdMC","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":484,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"xaxis","fTitle":"R_{g}","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":20,"fXmin":0.01,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUn ...
// <div id="root_plot_8"
//      style="width: 596px; height: 372px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
//        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.113750009220094,"fY1":-0.537781224578994,"fX2":1.12375000922009,"fY2":4.84003070066837,"fXtoAbsPixelk":54.7838920080418,"fXtoPixelk":54.7838920080418,"fXtoPixel":481.616154439521,"fYtoAbsPixelk":334.800047782707,"fYtoPixelk":334.800047782707,"fYtoPixel":-69.1731144879875,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":596,"fVtoAbsPixelk":372.00005,"fVtoPixelk":372,"fVtoPixel":-372,"fAbsPixeltoXk":-0.113750009220094,"fPixeltoXk":-0.113750009220094,"fPixeltoX":0.00207634231281911,"fAbsPixeltoYk":4.84003070066837,"fPixeltoYk":-0.537781224578994,"fPixeltoY":-0.0144564836700198,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0.01,"fUymin":0,"fUxmax":1,"fUymax":4.30224947608937,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":0.01,"fY1":0,"fX2":1,"fY2":4.30224947608937,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1D","fUniqueID":0,"fBits":50332168,"fName":"hproj_incl","fTitle":"Projection","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":20,"fMarkerSize":1,"fNcells":22,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"xaxis","fTitle":"R_{g}","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":20,"fXmin":0.01,"fXmax":1,"fXbins":[],"fFirst":1,"fLast":20,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"yaxis","fTitle":"1\/N dN\/dR_{g} for genpt in [50, 100] GeV","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":5561221.91050264,"fTsumw":36004.7221649857,"fTsumw2":233.103450831481,"fTsumwx":6280.68557320087,"fTsumwx2":1408.18276361109,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[3.72926420999513e-7,4.9502177216658e-6,1.28803463375166e-5,1.4688656151852e-5,1.27144395633232e-5,1.03339464623335e-5,8.98026401297155e-6,6.15600277810926e-6,2.47038781963356e-6,2.27784793359203e-7,1.00563074412663e-8,1.15902788775854e-10,3.55198321639489e-12,2.04924783964588e-13,0,0,0,0,0,0,0,0],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fBufferSi ...
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: czg
// Info in <TCanvas::Print>: jpg file genptVSzg.jpg has been created
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: cproj_zg
// Info in <TCanvas::Print>: jpg file zg_proj_gen.jpg has been created
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: crg
// Info in <TCanvas::Print>: jpg file genptVSrg.jpg has been created
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: cproj_rg
// Info in <TCanvas::Print>: png file rg_proj_gen.png has been created
