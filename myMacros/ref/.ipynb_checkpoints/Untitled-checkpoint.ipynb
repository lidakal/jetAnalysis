// %%
string path_incl = "/data_CMS/cms/mnguyen//bJet2022/qcdMC/SD/merged_HiForestAOD.root";
string path_bJet = "/data_CMS/cms/mnguyen//bJet2022/bJetMC/SD/merged_HiForestAOD.root";
TFile *f;
TTree *t;
TTree *HiTree;

// %%
%jsroot on

// %%
f = new TFile(path_incl.c_str());
t = (TTree *) f->Get("ak4PFJetAnalyzer/t");
HiTree = (TTree *) f->Get("hiEvtAnalyzer/HiTree");

// %%
Long64_t nentries = t->GetEntries();

// %%
Float_t rsjt2Pt[30];

// %%
Float_t refeta[30];

// %%
Int_t nref;

// %%
t->SetBranchAddress("rsjt2Pt", rsjt2Pt);
t->SetBranchAddress("refeta", refeta);
t->SetBranchAddress("nref", &nref);

// %%
t->SetBranchStatus("*", 0);
t->SetBranchStatus("rsjt2Pt", 1);
t->SetBranchStatus("nref", 1);
t->SetBranchStatus("refeta", 1);

// %%
Int_t *n = &nref;

// %%
Float_t *pt2 = rsjt2Pt;

// %%
t->GetEntry(4);

// %%
cout << rsjt2Pt[1]
// Out:
// 22.6245(std::basic_ostream<char, std::char_traits<char> >::__ostream_type &) @0x7f1fa2766e00

// %%
cout << pt2[1]
// Out:
// 22.6245(std::basic_ostream<char, std::char_traits<char> >::__ostream_type &) @0x7f1fa2766e00

// %%
Long64_t counter = 0;

// %%
for (Long64_t i = 0; i < nentries; i++) {
    t->GetEntry(i);
    for (int j = 0; j < nref; j++) {
        if ((rsjt2Pt[j] > 0) && (refeta[j] < 2.)) {
            counter++;
        }
    }
}

// %%
cout << counter;
// Out:
// 142103725

// %%
TFile *fin = new TFile("ref_sub.root");

// %%
TH2F *h2d = (TH2F *) fin->Get("h_incl_zgB");

// %%
TCanvas *c = new TCanvas("c", "", 600, 600);

// %%
TH1F *h1d =(TH1F *) h2d->ProjectionX("h1d", 0, 5);
h1d->GetXaxis()->SetCanExtend(true);

// %%
h1d->GetXaxis()->SetRange(0, h1d->GetXaxis()->GetNbins());

// %% [markdown]
// Find what is the maximum pt for a given bin.

// %%
int lastbin = 5;

// %%
cout << h2d->GetYaxis()->GetBinUpEdge(lastbin);
// Out:
// 130

// %% [markdown]
// Find what is the bin for a given pt.

// %%
float maxpt = 150;

// %%
cout << h2d->GetYaxis()->FindBin(maxpt);
// Out:
// 7

// %%
%jsroot off

// %%
h1d->SetMarkerStyle(kFullCircle);
h1d->Draw();
c->Draw();

// %%
cout << h1d->GetBinError(0);
// Out:
// 7.01007

// %%
h1d->GetXaxis()->SetCanExtend(true);
h1d->GetXaxis()->SetRange(0, h1d->GetNbinsX());

// %%
h1d->Draw()

// %%
c->Draw()

// %%
std::string title = "max = " + std::string(maxpt);
// Out:
// input_line_68:2:33: error: no matching conversion for functional-style cast from 'float' to 'std::string' (aka 'basic_string<char>')
//  std::string title = "max = " + std::string(maxpt);
//                                 ^~~~~~~~~~~~~~~~~
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:389:7: note: candidate constructor not viable: no known conversion from 'float' to 'const std::allocator<char>' for 1st argument
//       basic_string(const _Alloc& __a) _GLIBCXX_NOEXCEPT
//       ^
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:397:7: note: candidate constructor not viable: no known conversion from 'float' to 'const std::__cxx11::basic_string<char>' for 1st argument
//       basic_string(const basic_string& __str)
//       ^
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:454:7: note: candidate constructor not viable: no known conversion from 'float' to 'const char *' for 1st argument
//       basic_string(const _CharT* __s, const _Alloc& __a = _Alloc())
//       ^
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:476:7: note: candidate constructor not viable: no known conversion from 'float' to 'std::__cxx11::basic_string<char>' for 1st argument
//       basic_string(basic_string&& __str) noexcept
//       ^
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:503:7: note: candidate constructor not viable: no known conversion from 'float' to 'initializer_list<char>' for 1st argument
//       basic_string(initializer_list<_CharT> __l, const _Alloc& __a = _Alloc())
//       ^
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:549:9: note: candidate constructor template not viable: requires at least 2 arguments, but 1 was provided
//         basic_string(_InputIterator __beg, _InputIterator __end,
//         ^
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:380:7: note: candidate constructor not viable: requires 0 arguments, but 1 was provided
//       basic_string()
//       ^
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:507:7: note: candidate constructor not viable: requires 2 arguments, but 1 was provided
//       basic_string(const basic_string& __str, const _Alloc& __a)
//       ^
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:511:7: note: candidate constructor not viable: requires 2 arguments, but 1 was provided
//       basic_string(basic_string&& __str, const _Alloc& __a)
//       ^
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:410:7: note: candidate constructor not viable: requires at least 2 arguments, but 1 was provided
//       basic_string(const basic_string& __str, size_type __pos,
//       ^
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:444:7: note: candidate constructor not viable: requires at least 2 arguments, but 1 was provided
//       basic_string(const _CharT* __s, size_type __n,
//       ^
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:464:7: note: candidate constructor not viable: requires at least 2 arguments, but 1 was provided
//       basic_string(size_type __n, _CharT __c, const _Alloc& __a = _Alloc())
//       ^
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:426:7: note: candidate constructor not viable: requires 4 arguments, but 1 was provided
//       basic_string(const basic_string& __str, size_type __pos,
//       ^
// input_line_68:2:14: error: redefinition of 'title' with a different type: 'std::string' (aka 'basic_string<char>') vs 'std::string &' (aka 'basic_string<char> &')
//  std::string title = "max = " + std::string(maxpt);
//              ^
// input_line_66:2:14: note: previous definition is here
//  std::string title = "max = " + str(maxpt);
//              ^

// %%
cout << title

// %%
int a = 5;

// %%
str(a)
// Out:
// input_line_71:2:3: error: use of undeclared identifier 'str'
//  (str(((*(int*)0x7f156cd59080))))
//   ^

// %%
(string) a
// Out:
// input_line_32:2:2: error: no matching conversion for C-style cast from 'int' to 'string' (aka 'basic_string<char>')
//  (string) a
//  ^~~~~~~~~~
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:389:7: note: candidate constructor not viable: no known conversion from 'int' to 'const std::allocator<char>' for 1st argument
//       basic_string(const _Alloc& __a) _GLIBCXX_NOEXCEPT
//       ^
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:397:7: note: candidate constructor not viable: no known conversion from 'int' to 'const std::__cxx11::basic_string<char>' for 1st argument
//       basic_string(const basic_string& __str)
//       ^
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:454:7: note: candidate constructor not viable: no known conversion from 'int' to 'const char *' for 1st argument
//       basic_string(const _CharT* __s, const _Alloc& __a = _Alloc())
//       ^
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:476:7: note: candidate constructor not viable: no known conversion from 'int' to 'std::__cxx11::basic_string<char>' for 1st argument
//       basic_string(basic_string&& __str) noexcept
//       ^
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:503:7: note: candidate constructor not viable: no known conversion from 'int' to 'initializer_list<char>' for 1st argument
//       basic_string(initializer_list<_CharT> __l, const _Alloc& __a = _Alloc())
//       ^
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:549:9: note: candidate constructor template not viable: requires at least 2 arguments, but 1 was provided
//         basic_string(_InputIterator __beg, _InputIterator __end,
//         ^
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:380:7: note: candidate constructor not viable: requires 0 arguments, but 1 was provided
//       basic_string()
//       ^
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:507:7: note: candidate constructor not viable: requires 2 arguments, but 1 was provided
//       basic_string(const basic_string& __str, const _Alloc& __a)
//       ^
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:511:7: note: candidate constructor not viable: requires 2 arguments, but 1 was provided
//       basic_string(basic_string&& __str, const _Alloc& __a)
//       ^
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:410:7: note: candidate constructor not viable: requires at least 2 arguments, but 1 was provided
//       basic_string(const basic_string& __str, size_type __pos,
//       ^
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:444:7: note: candidate constructor not viable: requires at least 2 arguments, but 1 was provided
//       basic_string(const _CharT* __s, size_type __n,
//       ^
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:464:7: note: candidate constructor not viable: requires at least 2 arguments, but 1 was provided
//       basic_string(size_type __n, _CharT __c, const _Alloc& __a = _Alloc())
//       ^
// /build/cmsbld/auto-builds/CMSSW_9_4_9-slc7_amd64_gcc630/build/CMSSW_9_4_9-build/slc7_amd64_gcc630/external/gcc/6.3.0/bin/../lib/gcc/x86_64-unknown-linux-gnu/6.3.0/../../../../include/c++/6.3.0/bits/basic_string.h:426:7: note: candidate constructor not viable: requires 4 arguments, but 1 was provided
//       basic_string(const basic_string& __str, size_type __pos,
//       ^

// %%
(float) a
// Out:
// (float) 5.00000f

// %%
std::to_string(14.2)
// Out:
// (std::string) "14.200000"

// %%
std::sprintf(14.2)
// Out:
// input_line_39:2:19: error: too few arguments to function call, expected at least 2, have 1
//  std::sprintf(14.2)
//  ~~~~~~~~~~~~     ^

// %%
printf("%.2f", 5.12)
// Out:
// 5.12(int) 4

// %%
float x = 1.234;

// %%
to_string((int)x)
// Out:
// (std::string) "1"

// %%
void test()
{
    TFile *fin = new TFile("ref_sub.root");
    TH2F *h2d = (TH2F *) fin->Get("h_incl_zgB_dynKt");
    
    float maxpt = 120;
    int lastbin = h2d->GetYaxis()->FindBin(maxpt);
    maxpt = h2d->GetYaxis()->GetBinUpEdge(lastbin);
    
    TH1F *h1d =(TH1F *) h2d->ProjectionX("h1d", 1, lastbin, "e");
    h1d->GetXaxis()->SetCanExtend(true);
    int nbins = h1d->GetXaxis()->GetNbins();
    h1d->GetXaxis()->SetRange(0, h1d->GetXaxis()->GetNbins());
    h1d->Scale(1/h1d->Integral("width"));
    h1d->SetFillColor(0);
    
    TCanvas *c = new TCanvas("c", "", 600, 600);
    h1d->Draw("hist");
    h1d->Draw("e same");
    c->Draw();
}

// %%
test()
// Out:
// <div id="root_plot_1"
//      style="width: 596px; height: 572px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
//        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-0.0765625047730285,"fY1":-0.41511308052884,"fX2":0.564062504773028,"fY2":3.73601747733289,"fXtoAbsPixelk":71.2293216718303,"fXtoPixelk":71.2293216718303,"fXtoPixel":930.341449551465,"fYtoAbsPixelk":514.800046590614,"fYtoPixelk":514.800046590614,"fYtoPixel":-137.793787024285,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":596,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-0.0765625047730285,"fPixeltoXk":-0.0765625047730285,"fPixeltoX":0.0010748741770907,"fAbsPixeltoYk":3.73601747733289,"fPixeltoYk":-0.41511308052884,"fPixeltoY":-0.00725722125500303,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-0.0125,"fUymin":0,"fUxmax":0.5,"fUymax":3.32090439680405,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":-0.0125,"fY1":0,"fX2":0.5,"fY2":3.32090439680405,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1D","fUniqueID":0,"fBits":50331656,"fName":"h1d","fTitle":"refpt vs zg, b jets, dynKt","fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":1,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":20,"fMarkerSize":1,"fNcells":42,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50333696,"fName":"xaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":43,"fLabelOffset":0.01,"fLabelSize":20,"fTickLength":0.03,"fTitleOffset":1.4,"fTitleSize":20,"fTitleColor":1,"fTitleFont":43,"fNbins":40,"fXmin":0,"fXmax":0.5,"fXbins":[],"fFirst":0,"fLast":40,"fBits2":2,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"yaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":50331648,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":70605.65301517,"fTsumw":0,"fTsumw2":0,"fTsumwx":0,"fTsumwx2":0,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[0,0,0,0,0,0,0,0,0,5.35986898091598e-4,9.6060307480866e-4,0.00112631308856828,0.00158117939006169,0.0025241400746984,0.00253658833854656,0.0025283188061216,0.00246276109189591,0.00340771242021402,0.00370500735720172,0.00306357125976195,0.00332242632009896,0.00386903597725942,0.00367626497707707,0.00396541713373157,0.00373497301179203,0.00320368656730127,0.00300781387934407,0.00390066379792236,0.00352526801815557,0.00277320887979711,0.00292973032873591,0.00262761260206983,0.00227861 ...

// %%
// Out:
// input_line_56:2:3: error: member reference base type 'const char *' is not a structure or union
//  x.c_str();
//  ~^~~~~~

// %%
#include "Substructure.h"

// %%
Substructure s;

// %%
s.drawBvsL();

// %%
std::string finname = "ref_sub.root";

// %%
void test(bool qcd = true, bool zgORrg = true, bool dynKt = true)
{
    gStyle->SetOptTitle(1);
                        
    TFile *fin = new TFile(finname.c_str());
    std::string hname1 = "h";
    std::string hname2 = "h";
    
    std::string title2d = "";
    std::string xtitle = "";
    std::string ytitle2d = "refpt (GeV)";
    std::string ytitle1d = "1/N dN/d";

    if (qcd) {
        hname1 += "_incl";
        hname2 += "_incl";
        title2d += "qcdMC";
    } else {
        hname1 += "_bJet";
        hname2 += "_bJet";
        title2d += "bJetMC";
    }
    if (zgORrg) { 
        hname1 += "_zgB";
        hname2 += "_zgL";
        title2d += ", refpt vs z_{g}";
        xtitle += "z_{g}";
        ytitle1d += "z_{g}";
    } else {
        hname1 += "_rgB";
        hname2 += "_rgL";
        title2d += ", refpt vs R_{g}";
        xtitle += "R_{g}";
        ytitle1d += "R_{g}";
    }
    if (dynKt) {
        hname1 += "_dynKt";
        hname2 += "_dynKt";
        title2d += ", dynKt only";
    }
    
    // 2d histograms
    float maxpt2d = 130;
    
    TH2F *h2d1 = (TH2F *) fin->Get(hname1.c_str());
    TH2F *h2d2 = (TH2F *) fin->Get(hname2.c_str());
    
    TCanvas *c2d = new TCanvas("c2d", "", 1000, 500);
    c2d->Divide(2, 1);
    
    const int n = 2;
    TH2F *hs2d[n] = {h2d1, h2d2};
    
    for (int ni = 0; ni < n; ni++) {
        c2d->cd(ni + 1);
        
        TH2F *h = hs2d[ni];
        h->GetXaxis()->SetCanExtend(true);
        h->GetXaxis()->SetRange(0, h->GetXaxis()->GetNbins()); //include jets that don't have a proper substructure
        h->GetYaxis()->SetRange(1, h->GetYaxis()->FindBin(maxpt2d));
        h->SetXTitle(xtitle.c_str());
        h->SetYTitle(ytitle2d.c_str());
        h->SetTitle("b-jets");
        
        h->Draw("COLZ");
    }
    
    TPaveText *pt = new TPaveText(.05,.1,.95,.8);
    pt->Draw();
    
    
    c2d->SetTitle(title2d.c_str());
    c2d->Draw();
    c2d->Show();
                
    
    /*
    
    
    
    TH1F *h1d =(TH1F *) h2d->ProjectionX("h1d", 0, 5, "e");
    h1d->GetXaxis()->SetCanExtend(true);
    int nbins = h1d->GetXaxis()->GetNbins();
    std::cout << nbins << endl;
    h1d->GetXaxis()->SetRange(0, h1d->GetXaxis()->GetNbins());
    
    TCanvas *c = new TCanvas("c", "", 600, 600);
    h1d->Draw("E");
    c->Draw();
    */
}

// %%
test()

// %%
std::string a = "hi, you";

// %%
#include <regex>

std::string b = a;

// %%
b = std::regex_replace(b, std::regex("a"), "_");

// %%
b
// Out:
// (std::string &) "hi_you"

// %%
cout << Form("hi %.0f %s", 2.1, "you");
// Out:
// hi 2 you

// %%
a
// Out:
// (std::string &) "hi 2.10 you"

// %%
const char * b = Form("hi %.2f %s", 2.1, "you");

// %%
b
// Out:
// (const char *) "p\xa3&\x01"

// %%
std::format("{%d}", 2)
// Out:
// input_line_51:2:7: error: no member named 'format' in namespace 'std'
//  std::format("{%d}", 2)
//  ~~~~~^

// %%
#include <format>
// Out:
// input_line_52:1:10: fatal error: 'format' file not found
// #include <format>
//          ^
